# %%
import os

from google.colab import drive
drive.mount('/content/drive')

if os.path.exists("/content/image-super-resolution"):
    # %cd /content/image-super-resolution
    # !git pull
else:
    # !git clone https://github.com/ChristianSalon/image-super-resolution.git
    # !git checkout -b vsr origin/vsr
    # %cd "/content/image-super-resolution"

# !pip install -r requirements.txt

# !bash scripts/download_data.sh

# %% [markdown]
# ### Train RLSP

# %%
# !python train.py rlsp --epochs 20 --scale 4 --patch-size 64 --batch-size 64 --save-path /content/drive/MyDrive/checkpoints/rlsp

# %% [markdown]
# ### Train SRCNN model

# %%
# !python train.py srcnn --epochs 20 --scale 2 --patch-size 64 --batch-size 64 --save-path /content/drive/MyDrive/checkpoints/srcnn

# %%
# !python train.py srcnn --epochs 20 --scale 4 --patch-size 64 --batch-size 64 --save-path /content/drive/MyDrive/checkpoints/srcnn

# %%
# !python train.py srcnn --epochs 20 --scale 8 --patch-size 64 --batch-size 64 --save-path /content/drive/MyDrive/checkpoints/srcnn

# %% [markdown]
# test video

# %%
# !python video_eval.py -i data/video_test/testvideo1.mp4 -o results/videos/ -s 8 --model srcnn --srcnn-path export/srcnn/8x/srcnn_8x_e19.pth
# Out:
# Processing [SRCNN]: SingleVideo...
#
# ================================================================================
# Model    | Task/Variant              | PSNR       | SSIM       | FPS
# --------------------------------------------------------------------------------
# SRCNN    | SingleVideo               | 0.0000     | 0.0000     | 30.70
# --------------------------------------------------------------------------------
# TOTAL    | AVERAGE AGGREGATED        | nan        | nan        | 30.70
# ================================================================================
# c:\Users\matej\anaconda3\envs\KNNproject\Lib\site-packages\numpy\_core\fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\matej\anaconda3\envs\KNNproject\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# !python video_eval.py -i data/video_test/testvideo1.mp4 -o results/videos/ -s 8 --model vdsr  --vdsr-path export/vdsr/mix_2x(19e)_8x/vdsr_8x_e13.pth
# Out:
# Processing [VDSR]: SingleVideo...
#
# ================================================================================
# Model    | Task/Variant              | PSNR       | SSIM       | FPS
# --------------------------------------------------------------------------------
# VDSR     | SingleVideo               | 0.0000     | 0.0000     | 3.30

# %%
# !python video_eval.py -i data/video_test/ -o results/aggregated/ -s 4 --model srcnn --srcnn-path export/srcnn/4x/srcnn_4x_e19.pth --vdsr-path export/vdsr/4x/vdsr_4x_e19.pth
# Out:
# Processing [SRCNN]: BDx4/calendar...
# Processing [SRCNN]: BDx4/city...
# Processing [SRCNN]: BDx4/foliage...
# Processing [SRCNN]: BDx4/walk...
# Processing [SRCNN]: BIx4/calendar...
# Processing [SRCNN]: BIx4/city...
# Processing [SRCNN]: BIx4/foliage...
# Processing [SRCNN]: BIx4/walk...
#
# ================================================================================
# Model    | Task/Variant              | PSNR       | SSIM       | FPS
# --------------------------------------------------------------------------------
# SRCNN    | BDx4/calendar             | 18.0701    | 0.6617     | 82.53
# SRCNN    | BDx4/city                 | 23.0146    | 0.6519     | 131.89
# SRCNN    | BDx4/foliage              | 20.9642    | 0.6353     | 157.44
# SRCNN    | BDx4/walk                 | 23.2439    | 0.8275     | 156.71
# SRCNN    | BIx4/calendar             | 18.3016    | 0.6902     | 132.62
# SRCNN    | BIx4/city                 | 23.2077    | 0.6770     | 134.77
# SRCNN    | BIx4/foliage              | 21.2796    | 0.6728     | 155.58
# SRCNN    | BIx4/walk                 | 23.6985    | 0.8488     | 154.48
# --------------------------------------------------------------------------------
# TOTAL    | AVERAGE AGGREGATED        | 21.4725    | 0.7081     | 138.25
# ================================================================================

# %%
# !python video_eval.py -i data/video_test/ -o results/aggregated/ -s 4 --model vdsr --srcnn-path export/srcnn/4x/srcnn_4x_e19.pth --vdsr-path export/vdsr/4x/vdsr_4x_e19.pth
# Out:
# Processing [VDSR]: BDx4/calendar...
# Processing [VDSR]: BDx4/city...
# Processing [VDSR]: BDx4/foliage...
# Processing [VDSR]: BDx4/walk...
# Processing [VDSR]: BIx4/calendar...
# Processing [VDSR]: BIx4/city...
# Processing [VDSR]: BIx4/foliage...
# Processing [VDSR]: BIx4/walk...
#
# ================================================================================
# Model    | Task/Variant              | PSNR       | SSIM       | FPS
# --------------------------------------------------------------------------------
# VDSR     | BDx4/calendar             | 18.4362    | 0.7057     | 18.48
# VDSR     | BDx4/city                 | 23.2779    | 0.6705     | 20.38
# VDSR     | BDx4/foliage              | 21.4127    | 0.6647     | 23.80
# VDSR     | BDx4/walk                 | 23.9048    | 0.8494     | 23.93
# VDSR     | BIx4/calendar             | 18.7053    | 0.7362     | 19.89
# VDSR     | BIx4/city                 | 23.4903    | 0.6960     | 20.42
# VDSR     | BIx4/foliage              | 21.7748    | 0.7032     | 23.92
# VDSR     | BIx4/walk                 | 24.4623    | 0.8708     | 23.89
# --------------------------------------------------------------------------------
# TOTAL    | AVERAGE AGGREGATED        | 21.9330    | 0.7371     | 21.84
# ================================================================================

# %% [markdown]
# rezidua

# %%
# !python visualize_residuals.py -i data/test/div2k_2018/hr/ -s 2 --srcnn-path export/srcnn/2x/srcnn_2x_e19.pth --vdsr-path export/vdsr/2x/vdsr_2x_e19.pth -o results/residuals/2x/
# !python visualize_residuals.py -i data/test/div2k_2018/hr/ -s 4 --srcnn-path export/srcnn/4x/srcnn_4x_e19.pth --vdsr-path export/vdsr/4x/vdsr_4x_e19.pth -o results/residuals/4x/
# !python visualize_residuals.py -i data/test/div2k_2018/hr/ -s 8 --srcnn-path export/srcnn/8x/srcnn_8x_e19.pth --vdsr-path export/vdsr/mix_2x(19e)_8x/vdsr_8x_e13.pth -o results/residuals/8x/
# Out:
# Začínam analýzu pre 100 obrázkov na zariadení: cuda...
# Ukladám vizualizácie pre ukážkový obrázok: 0801.png
# Spracované: 10/100...
# Spracované: 20/100...
# Spracované: 30/100...
# Spracované: 40/100...
# Spracované: 50/100...
# Spracované: 60/100...
# Spracované: 70/100...
# Spracované: 80/100...
# Spracované: 90/100...
# Spracované: 100/100...
#
# ==================================================
# CELKOVÉ PRIEMERY PRE DATASET (100 obrázkov, Mierka 2x)
# Čas spracovania: 118.49 sekúnd
# ==================================================
# SRCNN -> Priemerné MSE: 0.001827, Priemerná podobnosť: 0.0446
# VDSR  -> Priemerné MSE: 0.001114, Priemerná podobnosť: 0.2885
# --------------------------------------------------
# Záver: V rekonštrukcii rezíduí je priemerne presnejší model VDSR
# Začínam analýzu pre 100 obrázkov na zariadení: cuda...
# Ukladám vizualizácie pre ukážkový obrázok: 0801.png
# Spracované: 10/100...
# Spracované: 20/100...
# Spracované: 30/100...
# Spracované: 40/100...
# Spracované: 50/100...
# Spracované: 60/100...
# Spracované: 70/100...
# Spracované: 80/100...
# Spracované: 90/100...
# Spracované: 100/100...
#
# ==================================================
# CELKOVÉ PRIEMERY PRE DATASET (100 obrázkov, Mierka 4x)
# Čas spracovania: 145.64 sekúnd
# ==================================================
# SRCNN -> Priemerné MSE: 0.004415, Priemerná podobnosť: 0.1875
# VDSR  -> Priemerné MSE: 0.003872, Priemerná podobnosť: 0.3248
# --------------------------------------------------
# Záver: V rekonštrukcii rezíduí je priemerne presnejší model VDSR
# Začínam analýzu pre 100 obrázkov na zariadení: cuda...
# Ukladám vizualizácie pre ukážkový obrázok: 0801.png
# Spracované: 10/100...
# Spracované: 20/100...
# Spracované: 30/100...
# Spracované: 40/100...
# Spracované: 50/100...
# Spracované: 60/100...
# Spracované: 70/100...
# Spracované: 80/100...
# Spracované: 90/100...
# Spracované: 100/100...
#
# ==================================================
# CELKOVÉ PRIEMERY PRE DATASET (100 obrázkov, Mierka 8x)
# Čas spracovania: 152.31 sekúnd
# ==================================================
# SRCNN -> Priemerné MSE: 0.008197, Priemerná podobnosť: 0.3549
# VDSR  -> Priemerné MSE: 0.007822, Priemerná podobnosť: 0.4102
# --------------------------------------------------
# Záver: V rekonštrukcii rezíduí je priemerne presnejší model VDSR
